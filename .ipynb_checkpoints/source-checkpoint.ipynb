# %%
# adapted from https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
# https://www.youtube.com/watch?v=MqugtGD605k
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, TimeDistributed, RepeatVector, Dense, BatchNormalization
import numpy as np
import wandb
from wandb.keras import WandbCallback
import random

wandb.init()
config = wandb.config

class CharacterTable(object):
    """Given a set of characters:
    + Encode them to a one hot integer representation
    + Decode the one hot integer representation to their character output
    + Decode a vector of probabilities to their character output
    """
    def __init__(self, chars):
        """Initialize character table.
        # Arguments
            chars: Characters that can appear in the input.
        """
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))

    def encode(self, C, num_rows):
        """One hot encode given string C.
        # Arguments
            num_rows: Number of rows in the returned one hot encoding. This is
                used to keep the # of rows for each data the same.
        """
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x

    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return ''.join(self.indices_char[x] for x in x)

# Parameters for the model and dataset.
config.hidden_size = 512
config.batch_size = 64

# Maximum length of input is 'int + int' (e.g., '345+678'). Maximum length of
# int is DIGITS.
maxlen = 30
output_len = 10
# All the numbers, plus sign and space for padding.
chars = '0123456789+$-,/.ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuwxyv '
ctable = CharacterTable(chars)


import pandas as pd
df = pd.read_csv("sale_prices.csv")
df = df.fillna(0)



raw_prices = df["Price on site"].tolist()
parced_prices = []

int_min_price = [int(price) for price in df["Min price"]]
int_max_price = [int(price) for price in df["Max price"]]

# for idx in range(len(int_min_price)):
#     toappend = str(int_min_price[idx])
#     toappend+=' '*(output_len - len(str(int_min_price[idx])))
#     parced_prices.append(toappend)
    
#augmentation (acc: 0.9878)
# for i in range(4):
#     for idx in range(len(int_min_price)):
#         raw_price = str(raw_prices[idx])
#         parsed_price = str(int_min_price[idx])
#         num_of_replacements = random.randint(1,5)
#         for i in range(num_of_replacements):
#             to_replace = str(random.randint(1,9))
#             replace_with = str(random.randint(1,9))
#             parsed_price.replace(to_replace,replace_with)
#             raw_price.replace(to_replace,replace_with)

#         parsed_price+=' '*(output_len - len(str(int_min_price[idx])))
#         parced_prices.append(parsed_price)
#         raw_prices.append(raw_price)

#augmentation v2

split_at = len(int_min_price) - len(int_min_price) // 10

#train data
raw_prices_train = []
parced_prices_train = []

for i in range(4):
    for idx in range(split_at):
        raw_price = str(raw_prices[idx])
        parsed_price = str(int_min_price[idx])
        for i in range(len(parsed_price)):
            to_replace = parsed_price[i]
            if i == 0: # to do not make first digit as zero
                replace_with = str(random.randint(1,9))
            else:
                replace_with = str(random.randint(0,9))
            parsed_price = parsed_price.replace(to_replace,replace_with)
            raw_price = raw_price.replace(to_replace,replace_with)

        parsed_price+=' '*(output_len - len(str(int_min_price[idx])))
        parced_prices_train.append(parsed_price)
        raw_prices_train.append(raw_price)
        
#val data
raw_prices_val = []
parced_prices_val = []
for index in range(split_at,len(raw_prices)-1):
    raw_price = str(raw_prices[index])
    parsed_price = str(int_min_price[index])
    for i in range(len(parsed_price)):
        to_replace = parsed_price[i]
        if i == 0: # to do not make first digit as zero
            replace_with = str(random.randint(1,9))
        else:
            replace_with = str(random.randint(0,9))
        parsed_price = parsed_price.replace(to_replace,replace_with)
        raw_price = raw_price.replace(to_replace,replace_with)

    parsed_price+=' '*(output_len - len(str(int_min_price[index])))
    parced_prices_val.append(parsed_price)
    raw_prices_val.append(raw_price)
        
        
print('Total train prices:', len(raw_prices_train))
print('Total validation prices:', len(raw_prices_val))

print('Vectorization...')
x_train = np.zeros((len(raw_prices_train), maxlen, len(chars)), dtype=np.bool)
y_train = np.zeros((len(parced_prices_train), output_len, len(chars)), dtype=np.bool)
for i, sentence in enumerate(raw_prices_train):
    x_train[i] = ctable.encode(str(sentence), maxlen)
for i, sentence in enumerate(parced_prices_train):
    y_train[i] = ctable.encode(str(sentence), output_len)
    
x_val = np.zeros((len(raw_prices_val), maxlen, len(chars)), dtype=np.bool)
y_val = np.zeros((len(parced_prices_val), output_len, len(chars)), dtype=np.bool)
for i, sentence in enumerate(raw_prices_val):
    x_val[i] = ctable.encode(str(sentence), maxlen)
for i, sentence in enumerate(parced_prices_val):
    y_val[i] = ctable.encode(str(sentence), output_len)

model = Sequential()
model.add(LSTM(config.hidden_size, input_shape=(maxlen, len(chars))))
model.add(RepeatVector(output_len))

model.add(BatchNormalization())

model.add(LSTM(config.hidden_size, return_sequences=True))
model.add(TimeDistributed(Dense(len(chars), activation='softmax')))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
             metrics=['accuracy'])
model.summary()

# Train the model each generation and show predictions against the validation
# dataset.
for iteration in range(1, 200):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x_train, y_train,
              batch_size=config.batch_size,
              epochs=1,
              validation_data=(x_val, y_val),callbacks=[WandbCallback()])
    # Select 10 samples from the validation set at random so we can visualize
    # errors.
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowx, verbose=0)
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print('☑', end=' ')
        else:
            print('☒', end=' ')
        print('G',guess, end='\n')
# Out:
#                 Logging results to <a href="https://wandb.com" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://app.wandb.ai/pashanator/seq2seq_lstm_parsing" target="_blank">https://app.wandb.ai/pashanator/seq2seq_lstm_parsing</a><br/>
#                 Run page: <a href="https://app.wandb.ai/pashanator/seq2seq_lstm_parsing/runs/c3bnmn4c" target="_blank">https://app.wandb.ai/pashanator/seq2seq_lstm_parsing/runs/c3bnmn4c</a><br/>
# Total train prices: 2300
# Total validation prices: 62
# Vectorization...
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 512)               1189888
# _________________________________________________________________
# repeat_vector_5 (RepeatVecto (None, 10, 512)           0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 10, 512)           2048
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 10, 512)           2099200
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 10, 68)            34884
# =================================================================
# Total params: 3,326,020
# Trainable params: 3,324,996
# Non-trainable params: 1,024
# _________________________________________________________________
#
# --------------------------------------------------
# Iteration 1
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 38s 17ms/sample - loss: 1.8385 - acc: 0.5594 - val_loss: 1.8511 - val_acc: 0.5371
# Q $832,999                       T 832999     ☒ G 3
# Q $833,999                       T 833999     ☒ G 333
# Q $7,877,777                     T 7877777    ☒ G 7777
# Q $989,999                       T 989999     ☒ G 99
# Q $119,333                       T 119333     ☒ G 3333
# Q $3,936,666                     T 3936666    ☒ G 3333
# Q $69,111                        T 69111      ☒ G 1111
# Q $668,222                       T 668222     ☒ G 3322
# Q $445,522                       T 445522     ☒ G 3222
# Q $225,222                       T 225222     ☒ G 22222
#
# --------------------------------------------------
# Iteration 2
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 36s 16ms/sample - loss: 0.9212 - acc: 0.7120 - val_loss: 1.6629 - val_acc: 0.5403
# Q $1,711,111                     T 1711111    ☒ G 11111
# Q $225,222                       T 225222     ☒ G 33333
# Q $4,222,222                     T 4222222    ☒ G 33333
# Q $4,444,444                     T 4444444    ☒ G 44444
# Q $474,444                       T 474444     ☒ G 44444
# Q $69,111                        T 69111      ☒ G 66666
# Q $77,777                        T 77777      ☒ G 66666
# Q $272,222                       T 272222     ☒ G 33333
# Q $832,999                       T 832999     ☒ G 3333
# Q $9,999,999                     T 9999999    ☒ G 69999
#
# --------------------------------------------------
# Iteration 3
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 35s 15ms/sample - loss: 0.8219 - acc: 0.7311 - val_loss: 1.3821 - val_acc: 0.6516
# Q $833,999                       T 833999     ☒ G 99999
# Q $8,444,444                     T 8444444    ☒ G 44444
# Q $744,444                       T 744444     ☒ G 44444
# Q $979,798                       T 979798     ☒ G 79999
# Q $39,913,333                    T 39913333   ☒ G 11111
# Q $376,266                       T 376266     ☒ G 66666
# Q $655,111                       T 655111     ☒ G 11116
# Q $936,666                       T 936666     ☒ G 66666
# Q $119,333                       T 119333     ☒ G 11111
# Q $888,888                       T 888888     ☒ G 8
#
# --------------------------------------------------
# Iteration 4
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 37s 16ms/sample - loss: 0.7914 - acc: 0.7471 - val_loss: 1.2332 - val_acc: 0.6645
# Q $167,777                       T 167777     ☒ G 71117
# Q $979,798                       T 979798     ☒ G 66441
# Q $888,888                       T 888888     ☑ G 888888
# Q $8,444,444                     T 8444444    ☒ G 444444
# Q $4,222,222                     T 4222222    ☒ G 222222
# Q $4,949,999                     T 4949999    ☒ G 344433
# Q $6,277,777                     T 6277777    ☒ G 77777
# Q $1,711,111                     T 1711111    ☒ G 111111
# Q $1,122,222                     T 1122222    ☒ G 222222
# Q $334,466                       T 334466     ☒ G 333333
#
# --------------------------------------------------
# Iteration 5
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 34s 15ms/sample - loss: 0.7068 - acc: 0.7749 - val_loss: 1.4320 - val_acc: 0.5935
# Q $888,888                       T 888888     ☒ G 88888
# Q $225,222                       T 225222     ☒ G 22222
# Q $4,455,555                     T 4455555    ☒ G 55555
# Q $7,877,777                     T 7877777    ☒ G 77777
# Q $833,999                       T 833999     ☒ G 99999
# Q $733,333                       T 733333     ☒ G 77777
# Q $421,111                       T 421111     ☒ G 77777
# Q $69,111                        T 69111      ☒ G 77777
# Q $444,666 - $4,434,666          T 444666     ☒ G 44444
# Q $166,666                       T 166666     ☒ G 66555
#
# --------------------------------------------------
# Iteration 6
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 34s 15ms/sample - loss: 0.6259 - acc: 0.7913 - val_loss: 1.1177 - val_acc: 0.7113
# Q $3,936,666                     T 3936666    ☒ G 666699
# Q $177,777                       T 177777     ☒ G 77777
# Q $4,999,999                     T 4999999    ☒ G 999999
# Q $166,666                       T 166666     ☒ G 66666
# Q $4,949,999                     T 4949999    ☒ G 999999
# Q $4,999,999                     T 4999999    ☒ G 999999
# Q -                              T 9          ☒ G
# Q $69,111                        T 69111      ☒ G 11119
# Q $3,344,444                     T 3344444    ☒ G 444444
# Q $6,199,333                     T 6199333    ☒ G 333333
#
# --------------------------------------------------
# Iteration 7
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.5836 - acc: 0.7984 - val_loss: 0.9906 - val_acc: 0.7258
# Q $72,222                        T 72222      ☒ G 222222
# Q -                              T 1          ☒ G
# Q $9,999,999                     T 9999999    ☒ G 669999
# Q $9,999,999                     T 9999999    ☒ G 669999
# Q $4,222,222                     T 4222222    ☒ G 222222
# Q $9,900,000                     T 9900000    ☒ G 666660
# Q $9,999,999                     T 9999999    ☒ G 669999
# Q -                              T 1          ☒ G
# Q $7,877,777                     T 7877777    ☒ G 777777
# Q $4,222,222                     T 4222222    ☒ G 222222
#
# --------------------------------------------------
# Iteration 8
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.6474 - acc: 0.7817 - val_loss: 1.1621 - val_acc: 0.5871
# Q -                              T 1          ☒ G
# Q $3,333,333                     T 3333333    ☒ G 744443
# Q $9,999,999                     T 9999999    ☒ G 944444
# Q $7,877,777                     T 7877777    ☒ G 777777
# Q $39,913,333                    T 39913333   ☒ G 444444
# Q $166,666                       T 166666     ☒ G 666667
# Q $936,666                       T 936666     ☒ G 666447
# Q $166,666                       T 166666     ☒ G 666667
# Q $737,222                       T 737222     ☒ G 777777
# Q -                              T 9          ☒ G
#
# --------------------------------------------------
# Iteration 9
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.5852 - acc: 0.7954 - val_loss: 0.8904 - val_acc: 0.7355
# Q $737,222                       T 737222     ☒ G 222223
# Q $4,949,999                     T 4949999    ☒ G 644444
# Q $1,888,888                     T 1888888    ☒ G 8888888
# Q $166,666                       T 166666     ☒ G 666666
# Q $177,777                       T 177777     ☒ G 777777
# Q $177,777                       T 177777     ☒ G 777777
# Q $3,333,333                     T 3333333    ☒ G 333333
# Q $833,999                       T 833999     ☒ G 223333
# Q $37,777 - $388,577             T 37777      ☒ G 77777
# Q $1,711,111                     T 1711111    ☒ G 777711
#
# --------------------------------------------------
# Iteration 10
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.5231 - acc: 0.8087 - val_loss: 0.7109 - val_acc: 0.7774
# Q $119,333                       T 119333     ☒ G 343333
# Q $69,111                        T 69111      ☒ G 611111
# Q $7,877,777                     T 7877777    ☒ G 7777777
# Q $979,798                       T 979798     ☒ G 749999
# Q -                              T 2          ☒ G
# Q $636,666                       T 636666     ☒ G 666666
# Q $167,777                       T 167777     ☒ G 777777
# Q $936,666                       T 936666     ☒ G 666663
# Q $8,639,999                     T 8639999    ☒ G 6999999
# Q $119,333                       T 119333     ☒ G 343333
#
# --------------------------------------------------
# Iteration 11
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.5574 - acc: 0.7998 - val_loss: 0.7656 - val_acc: 0.7677
# Q $177,777                       T 177777     ☒ G 777777
# Q $333,333                       T 333333     ☑ G 333333
# Q $421,111                       T 421111     ☒ G 444444
# Q $1,122,222                     T 1122222    ☒ G 222222
# Q $334,466                       T 334466     ☒ G 333666
# Q $188,888                       T 188888     ☒ G 888888
# Q $668,222                       T 668222     ☒ G 666666
# Q $119,333                       T 119333     ☒ G 333333
# Q $119,333                       T 119333     ☒ G 333333
# Q $3,371,135                     T 3371135    ☒ G 3333533
#
# --------------------------------------------------
# Iteration 12
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.5070 - acc: 0.8105 - val_loss: 0.6695 - val_acc: 0.7774
# Q $655,111                       T 655111     ☒ G 111111
# Q $188,888                       T 188888     ☒ G 888888
# Q $334,466                       T 334466     ☒ G 444463
# Q $1,888,888                     T 1888888    ☒ G 8888888
# Q $39,913,333                    T 39913333   ☒ G 3333333
# Q $225,222                       T 225222     ☒ G 222222
# Q $655,111                       T 655111     ☒ G 111111
# Q $8,444,444                     T 8444444    ☒ G 4444444
# Q $6,277,777                     T 6277777    ☒ G 777777
# Q $6,199,333                     T 6199333    ☒ G 666333
#
# --------------------------------------------------
# Iteration 13
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.4866 - acc: 0.8205 - val_loss: 0.6714 - val_acc: 0.7968
# Q -                              T 2          ☒ G
# Q $4,999,999                     T 4999999    ☒ G 9999999
# Q $668,222                       T 668222     ☒ G 622666
# Q $7,877,777                     T 7877777    ☒ G 7777777
# Q $69,111                        T 69111      ☒ G 66665
# Q $167,777                       T 167777     ☒ G 666777
# Q $979,798                       T 979798     ☒ G 999999
# Q $225,222                       T 225222     ☒ G 222222
# Q $22,233,333                    T 22233333   ☒ G 3333333
# Q $421,111                       T 421111     ☒ G 141111
#
# --------------------------------------------------
# Iteration 14
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.4792 - acc: 0.8237 - val_loss: 0.5790 - val_acc: 0.7984
# Q $3,666,666                     T 3666666    ☒ G 6666666
# Q $4,222,222                     T 4222222    ☒ G 222222
# Q $421,111                       T 421111     ☒ G 111111
# Q $4,455,555                     T 4455555    ☒ G 555555
# Q $225,222                       T 225222     ☒ G 222222
# Q -                              T 5          ☒ G
# Q $445,522                       T 445522     ☒ G 555555
# Q $6,277,777                     T 6277777    ☒ G 7777777
# Q $733,333                       T 733333     ☒ G 333333
# Q $832,999                       T 832999     ☒ G 999999
#
# --------------------------------------------------
# Iteration 15
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 33s 15ms/sample - loss: 0.4345 - acc: 0.8397 - val_loss: 0.9219 - val_acc: 0.7129
# Q $4,444,444                     T 4444444    ☒ G 44444444
# Q $744,444                       T 744444     ☒ G 4444444
# Q $8,639,999                     T 8639999    ☒ G 9999999
# Q $4,455,555                     T 4455555    ☒ G 33555555
# Q $1,888,888                     T 1888888    ☒ G 11118888
# Q $8,639,999                     T 8639999    ☒ G 9999999
# Q $444,666 - $4,434,666          T 444666     ☒ G 4444466
# Q $22,233,333                    T 22233333   ☒ G 33333333
# Q $77,777                        T 77777      ☒ G 777777
# Q $421,111                       T 421111     ☒ G 3311111
#
# --------------------------------------------------
# Iteration 16
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 33s 14ms/sample - loss: 0.4268 - acc: 0.8423 - val_loss: 0.6250 - val_acc: 0.7871
# Q $119,333                       T 119333     ☒ G 333333
# Q $177,777                       T 177777     ☒ G 577777
# Q $6,199,333                     T 6199333    ☒ G 6666333
# Q $188,888                       T 188888     ☒ G 118888
# Q $7,877,777                     T 7877777    ☒ G 7755777
# Q $888,888                       T 888888     ☑ G 888888
# Q $444,666 - $4,434,666          T 444666     ☒ G 444444
# Q $655,111                       T 655111     ☒ G 555511
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $334,466                       T 334466     ☒ G 344366
#
# --------------------------------------------------
# Iteration 17
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.4320 - acc: 0.8400 - val_loss: 0.5114 - val_acc: 0.8161
# Q $733,333                       T 733333     ☒ G 333333
# Q $3,344,444                     T 3344444    ☒ G 4444444
# Q -                              T 9          ☒ G
# Q $69,111                        T 69111      ☒ G 99991
# Q $733,333                       T 733333     ☒ G 333333
# Q $3,344,444                     T 3344444    ☒ G 4444444
# Q $3,936,666                     T 3936666    ☒ G 6666666
# Q $445,522                       T 445522     ☒ G 222222
# Q $1,122,222                     T 1122222    ☒ G 2222222
# Q $979,798                       T 979798     ☒ G 779999
#
# --------------------------------------------------
# Iteration 18
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.4608 - acc: 0.8323 - val_loss: 0.7392 - val_acc: 0.7484
# Q $636,666                       T 636666     ☒ G 666999
# Q $655,111                       T 655111     ☒ G 9991111
# Q $166,666                       T 166666     ☒ G 666999
# Q $1,122,222                     T 1122222    ☒ G 8822222
# Q $636,666                       T 636666     ☒ G 666999
# Q $3,371,135                     T 3371135    ☒ G 1133333
# Q $376,266                       T 376266     ☒ G 662229
# Q $77,777                        T 77777      ☒ G 777777
# Q $936,666                       T 936666     ☒ G 666999
# Q $7,877,777                     T 7877777    ☒ G 8887777
#
# --------------------------------------------------
# Iteration 19
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.4235 - acc: 0.8453 - val_loss: 0.5036 - val_acc: 0.8274
# Q -                              T 9          ☒ G
# Q $1,122,222                     T 1122222    ☒ G 2222222
# Q $888,888                       T 888888     ☑ G 888888
# Q $8,444,444                     T 8444444    ☒ G 4444444
# Q $8,639,999                     T 8639999    ☒ G 99999999
# Q $474,444                       T 474444     ☒ G 444444
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $6,277,777                     T 6277777    ☒ G 66777777
# Q $733,333                       T 733333     ☒ G 333333
# Q $1,711,111                     T 1711111    ☒ G 4451111
#
# --------------------------------------------------
# Iteration 20
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3790 - acc: 0.8587 - val_loss: 0.5721 - val_acc: 0.7903
# Q $833,999                       T 833999     ☒ G 333999
# Q $376,266                       T 376266     ☒ G 666666
# Q $376,266                       T 376266     ☒ G 666666
# Q -                              T 5          ☒ G
# Q -                              T 2          ☒ G
# Q $833,999                       T 833999     ☒ G 333999
# Q $6,199,333                     T 6199333    ☒ G 666111
# Q -                              T 1          ☒ G
# Q $979,798                       T 979798     ☒ G 66799
# Q $272,222                       T 272222     ☒ G 222222
#
# --------------------------------------------------
# Iteration 21
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3737 - acc: 0.8587 - val_loss: 0.7214 - val_acc: 0.7468
# Q $37,777 - $388,577             T 37777      ☒ G 7777
# Q $9,999,999                     T 9999999    ☒ G 11999999
# Q $9,999,999                     T 9999999    ☒ G 11999999
# Q $22,299                        T 22299      ☒ G 222999
# Q $4,949,999                     T 4949999    ☒ G 11199999
# Q $989,999                       T 989999     ☒ G 1119999
# Q $445,522                       T 445522     ☒ G 555555
# Q $6,277,777                     T 6277777    ☒ G 66677777
# Q $833,999                       T 833999     ☒ G 3199999
# Q $119,333                       T 119333     ☒ G 199111
#
# --------------------------------------------------
# Iteration 22
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3770 - acc: 0.8593 - val_loss: 0.5679 - val_acc: 0.7984
# Q $3,936,666                     T 3936666    ☒ G 3336666
# Q $1,711,111                     T 1711111    ☒ G 9111111
# Q $225,222                       T 225222     ☒ G 5522222
# Q $334,466                       T 334466     ☒ G 433366
# Q $3,371,135                     T 3371135    ☒ G 33333333
# Q $22,299                        T 22299      ☒ G 292222
# Q $3,371,135                     T 3371135    ☒ G 33333333
# Q $22,299                        T 22299      ☒ G 292222
# Q $376,266                       T 376266     ☒ G 622666
# Q $833,999                       T 833999     ☒ G 333999
#
# --------------------------------------------------
# Iteration 23
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3426 - acc: 0.8692 - val_loss: 0.4133 - val_acc: 0.8629
# Q $4,999,999                     T 4999999    ☒ G 9999999
# Q $119,333                       T 119333     ☒ G 999333
# Q $989,999                       T 989999     ☒ G 999999
# Q $272,222                       T 272222     ☒ G 222222
# Q $1,888,888                     T 1888888    ☒ G 8888888
# Q $444,666 - $4,434,666          T 444666     ☒ G 444466
# Q $8,884,444                     T 8884444    ☑ G 8884444
# Q $167,777                       T 167777     ☒ G 667777
# Q -                              T 5          ☒ G
# Q $37,777 - $388,577             T 37777      ☑ G 37777
#
# --------------------------------------------------
# Iteration 24
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3378 - acc: 0.8712 - val_loss: 0.6141 - val_acc: 0.8210
# Q $272,222                       T 272222     ☒ G 222222
# Q $39,913,333                    T 39913333   ☒ G 99993333
# Q $668,222                       T 668222     ☒ G 666688
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $737,222                       T 737222     ☒ G 222222
# Q $4,455,555                     T 4455555    ☒ G 5455555
# Q $636,666                       T 636666     ☒ G 336666
# Q $833,999                       T 833999     ☒ G 3339999
# Q $188,888                       T 188888     ☒ G 8888888
# Q $166,666                       T 166666     ☑ G 166666
#
# --------------------------------------------------
# Iteration 25
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3337 - acc: 0.8714 - val_loss: 0.6176 - val_acc: 0.7855
# Q $6,277,777                     T 6277777    ☒ G 66677777
# Q $4,999,999                     T 4999999    ☒ G 44999999
# Q $655,111                       T 655111     ☒ G 6655111
# Q $37,777 - $388,577             T 37777      ☒ G 337777
# Q $6,277,777                     T 6277777    ☒ G 66677777
# Q $421,111                       T 421111     ☒ G 4444111
# Q $474,444                       T 474444     ☒ G 4444444
# Q $1,888,888                     T 1888888    ☒ G 1188888
# Q $119,333                       T 119333     ☒ G 119933
# Q $833,999                       T 833999     ☒ G 3339999
#
# --------------------------------------------------
# Iteration 26
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3196 - acc: 0.8763 - val_loss: 0.4750 - val_acc: 0.8129
# Q $4,222,222                     T 4222222    ☒ G 22222222
# Q -                              T 2          ☒ G
# Q $6,277,777                     T 6277777    ☒ G 22277777
# Q $4,949,999                     T 4949999    ☒ G 44499999
# Q $474,444                       T 474444     ☒ G 444444
# Q -                              T 1          ☒ G
# Q $9,999,999                     T 9999999    ☒ G 99999999
# Q $9,900,000                     T 9900000    ☒ G 00000000
# Q $474,444                       T 474444     ☒ G 444444
# Q $733,333                       T 733333     ☒ G 333333
#
# --------------------------------------------------
# Iteration 27
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3034 - acc: 0.8807 - val_loss: 0.4169 - val_acc: 0.8516
# Q $7,877,777                     T 7877777    ☒ G 8777777
# Q $444,666 - $4,434,666          T 444666     ☒ G 444446
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $39,913,333                    T 39913333   ☒ G 9923333
# Q $668,222                       T 668222     ☒ G 666222
# Q $6,277,777                     T 6277777    ☒ G 2277777
# Q $655,111                       T 655111     ☑ G 655111
# Q $7,877,777                     T 7877777    ☒ G 8777777
# Q $636,666                       T 636666     ☒ G 666666
# Q $1,711,111                     T 1711111    ☒ G 1111111
#
# --------------------------------------------------
# Iteration 28
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 34s 15ms/sample - loss: 0.2997 - acc: 0.8814 - val_loss: 0.4295 - val_acc: 0.8565
# Q $445,522                       T 445522     ☒ G 444522
# Q $8,884,444                     T 8884444    ☑ G 8884444
# Q $3,666,666                     T 3666666    ☒ G 33366666
# Q $6,277,777                     T 6277777    ☑ G 6277777
# Q $3,344,444                     T 3344444    ☒ G 3334444
# Q -                              T 2          ☒ G
# Q $39,913,333                    T 39913333   ☒ G 99993333
# Q $737,222                       T 737222     ☒ G 773322
# Q $832,999                       T 832999     ☒ G 333999
# Q $37,777 - $388,577             T 37777      ☒ G 77777
#
# --------------------------------------------------
# Iteration 29
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3086 - acc: 0.8795 - val_loss: 0.4080 - val_acc: 0.8629
# Q $334,466                       T 334466     ☒ G 33366
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $39,913,333                    T 39913333   ☒ G 933333333
# Q $2,127,111                     T 2127111    ☒ G 22211111
# Q $4,222,222                     T 4222222    ☒ G 2222222
# Q $7,877,777                     T 7877777    ☒ G 2777777
# Q -                              T 2          ☒ G
# Q $334,466                       T 334466     ☒ G 33366
# Q -                              T 2          ☒ G
# Q $3,936,666                     T 3936666    ☒ G 3336666
#
# --------------------------------------------------
# Iteration 30
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.3174 - acc: 0.8777 - val_loss: 0.4463 - val_acc: 0.8452
# Q $832,999                       T 832999     ☒ G 199999
# Q $272,222                       T 272222     ☒ G 722222
# Q $832,999                       T 832999     ☒ G 199999
# Q $733,333                       T 733333     ☒ G 773333
# Q $979,798                       T 979798     ☒ G 799999
# Q $8,444,444                     T 8444444    ☒ G 4444444
# Q $8,639,999                     T 8639999    ☒ G 6999999
# Q $4,455,555                     T 4455555    ☒ G 4444555
# Q $8,884,444                     T 8884444    ☒ G 8814444
# Q $166,666                       T 166666     ☒ G 6666666
#
# --------------------------------------------------
# Iteration 31
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2719 - acc: 0.8944 - val_loss: 0.4557 - val_acc: 0.8242
# Q $3,666,666                     T 3666666    ☒ G 66666666
# Q $445,522                       T 445522     ☑ G 445522
# Q $3,344,444                     T 3344444    ☒ G 1334444
# Q $8,639,999                     T 8639999    ☒ G 8899999
# Q $4,999,999                     T 4999999    ☒ G 79999999
# Q $8,884,444                     T 8884444    ☒ G 8888444
# Q $333,333                       T 333333     ☑ G 333333
# Q $9,793,471                     T 9793471    ☒ G 9997777
# Q $2,127,111                     T 2127111    ☒ G 2227111
# Q $6,199,333                     T 6199333    ☒ G 99991133
#
# --------------------------------------------------
# Iteration 32
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2670 - acc: 0.8942 - val_loss: 0.4061 - val_acc: 0.8694
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $167,777                       T 167777     ☑ G 167777
# Q $119,333                       T 119333     ☒ G 111333
# Q $445,522                       T 445522     ☒ G 444522
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 3333000
# Q $9,999,999                     T 9999999    ☒ G 99999999
# Q $4,222,222                     T 4222222    ☒ G 4442222
# Q $444,666 - $4,434,666          T 444666     ☒ G 4444666
# Q $636,666                       T 636666     ☒ G 666666
# Q $6,277,777                     T 6277777    ☒ G 6677777
#
# --------------------------------------------------
# Iteration 33
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2520 - acc: 0.9001 - val_loss: 0.4311 - val_acc: 0.8339
# Q $8,444,444                     T 8444444    ☒ G 8844444
# Q $979,798                       T 979798     ☒ G 877999
# Q $72,222                        T 72222      ☒ G 22222
# Q $4,444,444                     T 4444444    ☒ G 4455444
# Q $636,666                       T 636666     ☒ G 336666
# Q $4,949,999                     T 4949999    ☒ G 4499999
# Q $8,884,444                     T 8884444    ☒ G 8888444
# Q $979,798                       T 979798     ☒ G 877999
# Q $989,999                       T 989999     ☒ G 889999
# Q $6,199,333                     T 6199333    ☒ G 9999333
#
# --------------------------------------------------
# Iteration 34
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2586 - acc: 0.8970 - val_loss: 0.6123 - val_acc: 0.8097
# Q $119,333                       T 119333     ☒ G 11333
# Q $4,222,222                     T 4222222    ☒ G 442222
# Q $9,999,999                     T 9999999    ☒ G 999999
# Q $166,666                       T 166666     ☒ G 16666
# Q $22,299                        T 22299      ☒ G 22999
# Q $737,222                       T 737222     ☒ G 77722
# Q -                              T 2          ☒ G
# Q $334,466                       T 334466     ☒ G 43366
# Q $832,999                       T 832999     ☒ G 32999
# Q $188,888                       T 188888     ☒ G 18888
#
# --------------------------------------------------
# Iteration 35
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2670 - acc: 0.8955 - val_loss: 0.5912 - val_acc: 0.7984
# Q $225,222                       T 225222     ☒ G 555222
# Q $119,333                       T 119333     ☒ G 199533
# Q $936,666                       T 936666     ☒ G 496666
# Q $7,877,777                     T 7877777    ☒ G 77777777
# Q $744,444                       T 744444     ☒ G 445444
# Q $3,333,333                     T 3333333    ☒ G 3555333
# Q $4,949,999                     T 4949999    ☒ G 44459999
# Q $444,666 - $4,434,666          T 444666     ☒ G 4466666
# Q $119,333                       T 119333     ☒ G 199533
# Q $832,999                       T 832999     ☒ G 825999
#
# --------------------------------------------------
# Iteration 36
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2433 - acc: 0.9029 - val_loss: 0.4157 - val_acc: 0.8565
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $333,333                       T 333333     ☒ G 333334
# Q $445,522                       T 445522     ☒ G 4445522
# Q $655,111                       T 655111     ☒ G 555511
# Q $119,333                       T 119333     ☒ G 119334
# Q $119,333                       T 119333     ☒ G 119334
# Q $72,222                        T 72222      ☑ G 72222
# Q $3,344,444                     T 3344444    ☑ G 3344444
# Q -                              T 5          ☒ G
#
# --------------------------------------------------
# Iteration 37
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2490 - acc: 0.9015 - val_loss: 0.4717 - val_acc: 0.8387
# Q $832,999                       T 832999     ☒ G 229999
# Q $77,777                        T 77777      ☒ G 7777
# Q $1,711,111                     T 1711111    ☒ G 1111111
# Q $421,111                       T 421111     ☒ G 22111
# Q $3,344,444                     T 3344444    ☒ G 334444
# Q $4,222,222                     T 4222222    ☒ G 8222222
# Q $22,233,333                    T 22233333   ☒ G 2222233
# Q -                              T 9          ☒ G
# Q $6,199,333                     T 6199333    ☒ G 699913
# Q $737,222                       T 737222     ☒ G 772222
#
# --------------------------------------------------
# Iteration 38
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2451 - acc: 0.9051 - val_loss: 0.5279 - val_acc: 0.8113
# Q $69,111                        T 69111      ☒ G 661111
# Q $2,127,111                     T 2127111    ☒ G 2221111
# Q $119,333                       T 119333     ☒ G 1113333
# Q $1,888,888                     T 1888888    ☒ G 8888888
# Q $334,466                       T 334466     ☒ G 3333666
# Q $37,777 - $388,577             T 37777      ☒ G 377777
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 33330000
# Q $376,266                       T 376266     ☒ G 7366000
# Q $3,344,444                     T 3344444    ☒ G 33334444
# Q $655,111                       T 655111     ☒ G 6555111
#
# --------------------------------------------------
# Iteration 39
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2523 - acc: 0.9009 - val_loss: 0.7176 - val_acc: 0.7774
# Q $4,999,999                     T 4999999    ☒ G 49999999
# Q $119,333                       T 119333     ☒ G 1119333
# Q $832,999                       T 832999     ☒ G 8888999
# Q -                              T 2          ☒ G 1
# Q $3,371,135                     T 3371135    ☒ G 3321111
# Q $744,444                       T 744444     ☒ G 4444444
# Q $177,777                       T 177777     ☒ G 117777
# Q $8,444,444                     T 8444444    ☒ G 84444444
# Q $272,222                       T 272222     ☒ G 2222222
# Q -                              T 5          ☒ G 1
#
# --------------------------------------------------
# Iteration 40
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2189 - acc: 0.9119 - val_loss: 0.3207 - val_acc: 0.8855
# Q $733,333                       T 733333     ☒ G 773333
# Q $39,913,333                    T 39913333   ☒ G 9993333
# Q -                              T 9          ☒ G 4
# Q $39,913,333                    T 39913333   ☒ G 9993333
# Q $832,999                       T 832999     ☒ G 988999
# Q $166,666                       T 166666     ☑ G 166666
# Q $37,777 - $388,577             T 37777      ☒ G 77777
# Q -                              T 2          ☒ G 4
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $188,888                       T 188888     ☑ G 188888
#
# --------------------------------------------------
# Iteration 41
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.2042 - acc: 0.9208 - val_loss: 0.3336 - val_acc: 0.8806
# Q $8,884,444                     T 8884444    ☑ G 8884444
# Q $3,666,666                     T 3666666    ☒ G 3366666
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $444,666 - $4,434,666          T 444666     ☑ G 444666
# Q $37,777 - $388,577             T 37777      ☒ G 77777
# Q $37,777 - $388,577             T 37777      ☒ G 77777
# Q $3,666,666                     T 3666666    ☒ G 3366666
# Q $9,793,471                     T 9793471    ☒ G 999774
# Q $22,299                        T 22299      ☒ G 22999
# Q -                              T 2          ☒ G
#
# --------------------------------------------------
# Iteration 42
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1906 - acc: 0.9247 - val_loss: 0.2735 - val_acc: 0.8984
# Q $4,222,222                     T 4222222    ☑ G 4222222
# Q $668,222                       T 668222     ☑ G 668222
# Q $376,266                       T 376266     ☒ G 332666
# Q $2,127,111                     T 2127111    ☒ G 2221111
# Q $668,222                       T 668222     ☑ G 668222
# Q $3,666,666                     T 3666666    ☑ G 3666666
# Q $833,999                       T 833999     ☒ G 333999
# Q $39,913,333                    T 39913333   ☒ G 99993333
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $4,999,999                     T 4999999    ☑ G 4999999
#
# --------------------------------------------------
# Iteration 43
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1891 - acc: 0.9239 - val_loss: 0.3452 - val_acc: 0.8952
# Q $3,371,135                     T 3371135    ☒ G 3311111
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $166,666                       T 166666     ☑ G 166666
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 8030000
# Q $979,798                       T 979798     ☒ G 999900
# Q $6,277,777                     T 6277777    ☒ G 6677777
# Q $77,777                        T 77777      ☑ G 77777
# Q $225,222                       T 225222     ☒ G 222222
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $119,333                       T 119333     ☑ G 119333
#
# --------------------------------------------------
# Iteration 44
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1746 - acc: 0.9308 - val_loss: 0.2767 - val_acc: 0.9016
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $744,444                       T 744444     ☑ G 744444
# Q $166,666                       T 166666     ☑ G 166666
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $1,711,111                     T 1711111    ☒ G 1771111
# Q $3,371,135                     T 3371135    ☒ G 3333111
# Q $39,913,333                    T 39913333   ☒ G 14993333
# Q $9,793,471                     T 9793471    ☒ G 9973333
# Q $474,444                       T 474444     ☒ G 444444
# Q $1,122,222                     T 1122222    ☑ G 1122222
#
# --------------------------------------------------
# Iteration 45
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1698 - acc: 0.9324 - val_loss: 0.2745 - val_acc: 0.8952
# Q $4,455,555                     T 4455555    ☒ G 4445555
# Q $1,888,888                     T 1888888    ☑ G 1888888
# Q $376,266                       T 376266     ☒ G 432266
# Q $6,277,777                     T 6277777    ☒ G 6777777
# Q $119,333                       T 119333     ☒ G 119933
# Q $3,344,444                     T 3344444    ☑ G 3344444
# Q $733,333                       T 733333     ☑ G 733333
# Q $225,222                       T 225222     ☑ G 225222
# Q $3,666,666                     T 3666666    ☑ G 3666666
# Q $979,798                       T 979798     ☒ G 899999
#
# --------------------------------------------------
# Iteration 46
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1710 - acc: 0.9323 - val_loss: 0.2917 - val_acc: 0.8855
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 8333333
# Q $77,777                        T 77777      ☒ G 7777
# Q $1,711,111                     T 1711111    ☒ G 1111111
# Q $9,900,000                     T 9900000    ☑ G 9900000
# Q $444,666 - $4,434,666          T 444666     ☒ G 446666
# Q -                              T 5          ☒ G 8
# Q $445,522                       T 445522     ☒ G 445525
# Q $3,371,135                     T 3371135    ☒ G 3333111
# Q $1,711,111                     T 1711111    ☒ G 1111111
# Q $225,222                       T 225222     ☒ G 22222
#
# --------------------------------------------------
# Iteration 47
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1608 - acc: 0.9383 - val_loss: 0.3305 - val_acc: 0.8823
# Q $833,999                       T 833999     ☒ G 333999
# Q $1,711,111                     T 1711111    ☒ G 1111111
# Q -                              T 1          ☒ G 7
# Q $1,888,888                     T 1888888    ☑ G 1888888
# Q $2,127,111                     T 2127111    ☒ G 2222111
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $655,111                       T 655111     ☒ G 655511
# Q $6,199,333                     T 6199333    ☑ G 6199333
# Q $3,371,135                     T 3371135    ☒ G 3331111
#
# --------------------------------------------------
# Iteration 48
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1511 - acc: 0.9418 - val_loss: 0.2833 - val_acc: 0.9097
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $119,333                       T 119333     ☑ G 119333
# Q $3,344,444                     T 3344444    ☒ G 3334444
# Q $474,444                       T 474444     ☒ G 447444
# Q $668,222                       T 668222     ☒ G 666222
# Q $421,111                       T 421111     ☒ G 221111
# Q $225,222                       T 225222     ☒ G 255222
# Q -                              T 9          ☒ G
# Q $445,522                       T 445522     ☑ G 445522
# Q $3,936,666                     T 3936666    ☒ G 3336666
#
# --------------------------------------------------
# Iteration 49
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1446 - acc: 0.9449 - val_loss: 0.4170 - val_acc: 0.8516
# Q $979,798                       T 979798     ☒ G 777999
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $22,299                        T 22299      ☑ G 22299
# Q $167,777                       T 167777     ☒ G 766777
# Q $3,666,666                     T 3666666    ☑ G 3666666
# Q $1,888,888                     T 1888888    ☒ G 888888
# Q $6,199,333                     T 6199333    ☒ G 699933
# Q $225,222                       T 225222     ☒ G 222222
# Q $936,666                       T 936666     ☒ G 396666
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 833300
#
# --------------------------------------------------
# Iteration 50
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1513 - acc: 0.9433 - val_loss: 0.2748 - val_acc: 0.9032
# Q $167,777                       T 167777     ☒ G 117777
# Q $1,122,222                     T 1122222    ☑ G 1122222
# Q $72,222                        T 72222      ☑ G 72222
# Q $376,266                       T 376266     ☒ G 322666
# Q $334,466                       T 334466     ☒ G 344666
# Q $8,444,444                     T 8444444    ☑ G 8444444
# Q $188,888                       T 188888     ☑ G 188888
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $636,666                       T 636666     ☑ G 636666
#
# --------------------------------------------------
# Iteration 51
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1322 - acc: 0.9522 - val_loss: 0.3295 - val_acc: 0.8790
# Q $188,888                       T 188888     ☑ G 188888
# Q $8,884,444                     T 8884444    ☑ G 8884444
# Q $4,455,555                     T 4455555    ☑ G 4455555
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 833300
# Q $9,999,999                     T 9999999    ☒ G 999999
# Q $6,199,333                     T 6199333    ☒ G 699933
# Q $4,455,555                     T 4455555    ☑ G 4455555
# Q $225,222                       T 225222     ☒ G 222222
# Q $445,522                       T 445522     ☒ G 445222
# Q -                              T 1          ☒ G 8
#
# --------------------------------------------------
# Iteration 52
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1194 - acc: 0.9571 - val_loss: 0.3212 - val_acc: 0.8855
# Q $166,666                       T 166666     ☑ G 166666
# Q $744,444                       T 744444     ☒ G 444444
# Q $8,884,444                     T 8884444    ☑ G 8884444
# Q $733,333                       T 733333     ☑ G 733333
# Q $69,111                        T 69111      ☑ G 69111
# Q $188,888                       T 188888     ☒ G 118888
# Q $119,333                       T 119333     ☑ G 119333
# Q $936,666                       T 936666     ☒ G 333666
# Q $2,127,111                     T 2127111    ☒ G 2221111
# Q $9,793,471                     T 9793471    ☒ G 9943377
#
# --------------------------------------------------
# Iteration 53
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1146 - acc: 0.9591 - val_loss: 0.2787 - val_acc: 0.8984
# Q $1,122,222                     T 1122222    ☒ G 1822222
# Q -                              T 1          ☒ G 8
# Q $474,444                       T 474444     ☒ G 744444
# Q $8,884,444                     T 8884444    ☒ G 8888844
# Q $4,949,999                     T 4949999    ☒ G 4499999
# Q $2,127,111                     T 2127111    ☒ G 2227111
# Q $4,949,999                     T 4949999    ☒ G 4499999
# Q $69,111                        T 69111      ☑ G 69111
# Q $832,999                       T 832999     ☒ G 882999
# Q $8,444,444                     T 8444444    ☑ G 8444444
#
# --------------------------------------------------
# Iteration 54
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1218 - acc: 0.9571 - val_loss: 0.5629 - val_acc: 0.8452
# Q $22,233,333                    T 22233333   ☒ G 2223333
# Q $3,371,135                     T 3371135    ☒ G 333311
# Q $177,777                       T 177777     ☒ G 77777
# Q $188,888                       T 188888     ☑ G 188888
# Q $4,222,222                     T 4222222    ☒ G 422222
# Q $72,222                        T 72222      ☑ G 72222
# Q -                              T 5          ☒ G 8
# Q $119,333                       T 119333     ☒ G 19933
# Q $1,122,222                     T 1122222    ☒ G 112222
# Q $22,299                        T 22299      ☑ G 22299
#
# --------------------------------------------------
# Iteration 55
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.1387 - acc: 0.9490 - val_loss: 0.2587 - val_acc: 0.9081
# Q $1,711,111                     T 1711111    ☒ G 1111111
# Q $9,900,000                     T 9900000    ☑ G 9900000
# Q $3,666,666                     T 3666666    ☑ G 3666666
# Q $444,666 - $4,434,666          T 444666     ☑ G 444666
# Q $9,793,471                     T 9793471    ☒ G 9997777
# ...
# Q $737,222                       T 737222     ☑ G 737222
# Q $6,277,777                     T 6277777    ☒ G 6227777
# Q $1,888,888                     T 1888888    ☑ G 1888888
# Q $7,877,777                     T 7877777    ☑ G 7877777
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $1,122,222                     T 1122222    ☑ G 1122222
# Q $177,777                       T 177777     ☒ G 117777
# Q $4,455,555                     T 4455555    ☑ G 4455555
#
# --------------------------------------------------
# Iteration 101
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0148 - acc: 0.9960 - val_loss: 0.1460 - val_acc: 0.9516
# Q $9,900,000                     T 9900000    ☑ G 9900000
# Q -                              T 9          ☒ G 4
# Q $833,999                       T 833999     ☒ G 333999
# Q $1,888,888                     T 1888888    ☑ G 1888888
# Q $474,444                       T 474444     ☑ G 474444
# Q $668,222                       T 668222     ☑ G 668222
# Q $737,222                       T 737222     ☑ G 737222
# Q $72,222                        T 72222      ☑ G 72222
# Q $69,111                        T 69111      ☑ G 69111
# Q $833,999                       T 833999     ☒ G 333999
#
# --------------------------------------------------
# Iteration 102
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0172 - acc: 0.9951 - val_loss: 0.1806 - val_acc: 0.9403
# Q $2,127,111                     T 2127111    ☒ G 2171111
# Q -                              T 5          ☒ G 8
# Q $177,777                       T 177777     ☑ G 177777
# Q $6,277,777                     T 6277777    ☑ G 6277777
# Q $177,777                       T 177777     ☑ G 177777
# Q $668,222                       T 668222     ☒ G 666222
# Q $1,711,111                     T 1711111    ☒ G 1171111
# Q $72,222                        T 72222      ☑ G 72222
# Q $272,222                       T 272222     ☑ G 272222
# Q $4,444,444                     T 4444444    ☑ G 4444444
#
# --------------------------------------------------
# Iteration 103
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0166 - acc: 0.9953 - val_loss: 0.1998 - val_acc: 0.9323
# Q $832,999                       T 832999     ☒ G 332999
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q -                              T 2          ☒ G 7
# Q $376,266                       T 376266     ☒ G 376666
# Q $4,222,222                     T 4222222    ☑ G 4222222
# Q $334,466                       T 334466     ☒ G 333444
# Q $636,666                       T 636666     ☑ G 636666
# Q $3,936,666                     T 3936666    ☒ G 3336666
# Q $167,777                       T 167777     ☑ G 167777
# Q $334,466                       T 334466     ☒ G 333444
#
# --------------------------------------------------
# Iteration 104
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0189 - acc: 0.9948 - val_loss: 0.2045 - val_acc: 0.9339
# Q $225,222                       T 225222     ☑ G 225222
# Q $7,877,777                     T 7877777    ☑ G 7877777
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 0333033
# Q -                              T 1          ☒ G 3
# Q $2,127,111                     T 2127111    ☒ G 2271111
# Q $9,900,000                     T 9900000    ☑ G 9900000
# Q $1,888,888                     T 1888888    ☑ G 1888888
# Q $3,666,666                     T 3666666    ☑ G 3666666
# Q $3,371,135                     T 3371135    ☒ G 3333111
# Q $8,884,444                     T 8884444    ☑ G 8884444
#
# --------------------------------------------------
# Iteration 105
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0267 - acc: 0.9922 - val_loss: 0.2545 - val_acc: 0.9226
# Q $6,277,777                     T 6277777    ☒ G 62777777
# Q $77,777                        T 77777      ☒ G 777777
# Q $225,222                       T 225222     ☑ G 225222
# Q $8,639,999                     T 8639999    ☒ G 9636999
# Q $833,999                       T 833999     ☒ G 333999
# Q $833,999                       T 833999     ☒ G 333999
# Q -                              T 5          ☒ G 8
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $9,900,000                     T 9900000    ☒ G 9990000
# Q $421,111                       T 421111     ☑ G 421111
#
# --------------------------------------------------
# Iteration 106
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0261 - acc: 0.9920 - val_loss: 0.1714 - val_acc: 0.9371
# Q $936,666                       T 936666     ☑ G 936666
# Q $225,222                       T 225222     ☑ G 225222
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $421,111                       T 421111     ☑ G 421111
# Q -                              T 2          ☒ G 7
# Q $22,233,333                    T 22233333   ☒ G 22333333
# Q $39,913,333                    T 39913333   ☑ G 39913333
# Q $8,884,444                     T 8884444    ☒ G 8888444
# Q $22,299                        T 22299      ☑ G 22299
# Q $166,666                       T 166666     ☑ G 166666
#
# --------------------------------------------------
# Iteration 107
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0223 - acc: 0.9936 - val_loss: 0.1726 - val_acc: 0.9468
# Q $474,444                       T 474444     ☑ G 474444
# Q -                              T 5          ☒ G 7
# Q $69,111                        T 69111      ☑ G 69111
# Q $22,233,333                    T 22233333   ☑ G 22233333
# Q $1,122,222                     T 1122222    ☑ G 1122222
# Q $77,777                        T 77777      ☑ G 77777
# Q $979,798                       T 979798     ☒ G 999977
# Q $4,455,555                     T 4455555    ☑ G 4455555
# Q $376,266                       T 376266     ☒ G 372666
# Q $744,444                       T 744444     ☑ G 744444
#
# --------------------------------------------------
# Iteration 108
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0202 - acc: 0.9944 - val_loss: 0.2139 - val_acc: 0.9371
# Q $39,913,333                    T 39913333   ☑ G 39913333
# Q $22,299                        T 22299      ☑ G 22299
# Q $177,777                       T 177777     ☑ G 177777
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $39,913,333                    T 39913333   ☑ G 39913333
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $8,444,444                     T 8444444    ☑ G 8444444
# Q $636,666                       T 636666     ☑ G 636666
# Q $3,344,444                     T 3344444    ☑ G 3344444
#
# --------------------------------------------------
# Iteration 109
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0180 - acc: 0.9949 - val_loss: 0.1552 - val_acc: 0.9419
# Q $7,877,777                     T 7877777    ☑ G 7877777
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $989,999                       T 989999     ☑ G 989999
# Q $832,999                       T 832999     ☒ G 132999
# Q $888,888                       T 888888     ☑ G 888888
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $6,277,777                     T 6277777    ☑ G 6277777
# Q $2,127,111                     T 2127111    ☒ G 217211
# Q $832,999                       T 832999     ☒ G 132999
# Q $2,127,111                     T 2127111    ☒ G 217211
#
# --------------------------------------------------
# Iteration 110
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0150 - acc: 0.9958 - val_loss: 0.1776 - val_acc: 0.9387
# Q $832,999                       T 832999     ☒ G 822999
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $188,888                       T 188888     ☑ G 188888
# Q $9,793,471                     T 9793471    ☒ G 9977747
# Q $69,111                        T 69111      ☑ G 69111
# Q $421,111                       T 421111     ☒ G 488111
# Q $7,877,777                     T 7877777    ☑ G 7877777
# Q $6,199,333                     T 6199333    ☒ G 6191333
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $3,371,135                     T 3371135    ☒ G 3351111
#
# --------------------------------------------------
# Iteration 111
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 34s 15ms/sample - loss: 0.0186 - acc: 0.9942 - val_loss: 0.1556 - val_acc: 0.9355
# Q -                              T 2          ☒ G 7
# Q $6,277,777                     T 6277777    ☑ G 6277777
# Q $177,777                       T 177777     ☒ G 117777
# Q $22,299                        T 22299      ☑ G 22299
# Q $334,466                       T 334466     ☑ G 334466
# Q $979,798                       T 979798     ☒ G 979795
# Q $9,793,471                     T 9793471    ☒ G 9977147
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $832,999                       T 832999     ☒ G 833999
# Q $272,222                       T 272222     ☑ G 272222
#
# --------------------------------------------------
# Iteration 112
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0196 - acc: 0.9941 - val_loss: 0.1976 - val_acc: 0.9323
# Q $166,666                       T 166666     ☑ G 166666
# Q $6,277,777                     T 6277777    ☑ G 6277777
# Q -                              T 2          ☒ G 9
# Q $832,999                       T 832999     ☒ G 822999
# Q $334,466                       T 334466     ☑ G 334466
# Q $2,127,111                     T 2127111    ☒ G 227111
# Q $655,111                       T 655111     ☑ G 655111
# Q $832,999                       T 832999     ☒ G 822999
# Q $1,122,222                     T 1122222    ☑ G 1122222
# Q $9,793,471                     T 9793471    ☒ G 997933
#
# --------------------------------------------------
# Iteration 113
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 32s 14ms/sample - loss: 0.0161 - acc: 0.9948 - val_loss: 0.1395 - val_acc: 0.9565
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $3,344,444                     T 3344444    ☑ G 3344444
# Q $737,222                       T 737222     ☑ G 737222
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $77,777                        T 77777      ☑ G 77777
# Q $3,936,666                     T 3936666    ☑ G 3936666
# Q $636,666                       T 636666     ☑ G 636666
# Q $3,936,666                     T 3936666    ☑ G 3936666
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 0033003
# Q $225,222                       T 225222     ☑ G 225222
#
# --------------------------------------------------
# Iteration 114
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 33s 14ms/sample - loss: 0.0138 - acc: 0.9958 - val_loss: 0.1608 - val_acc: 0.9468
# Q $225,222                       T 225222     ☑ G 225222
# Q $444,666 - $4,434,666          T 444666     ☑ G 444666
# Q $4,949,999                     T 4949999    ☑ G 4949999
# Q -                              T 2          ☒ G 8
# Q $421,111                       T 421111     ☑ G 421111
# Q $421,111                       T 421111     ☑ G 421111
# Q $77,777                        T 77777      ☑ G 77777
# Q $9,900,000                     T 9900000    ☑ G 9900000
# Q $3,936,666                     T 3936666    ☑ G 3936666
# Q $1,711,111                     T 1711111    ☒ G 1171111
#
# --------------------------------------------------
# Iteration 115
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 44s 19ms/sample - loss: 0.0202 - acc: 0.9942 - val_loss: 0.1783 - val_acc: 0.9419
# Q $188,888                       T 188888     ☑ G 188888
# Q $1,711,111                     T 1711111    ☒ G 1171111
# Q $737,222                       T 737222     ☑ G 737222
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $668,222                       T 668222     ☑ G 668222
# Q $888,888                       T 888888     ☑ G 888888
# Q $4,444,444                     T 4444444    ☑ G 4444444
# Q $22,299                        T 22299      ☑ G 22299
# Q -                              T 2          ☒ G 4
#
# --------------------------------------------------
# Iteration 116
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 42s 18ms/sample - loss: 0.0181 - acc: 0.9948 - val_loss: 0.2055 - val_acc: 0.9290
# Q $655,111                       T 655111     ☑ G 655111
# Q $444,666 - $4,434,666          T 444666     ☑ G 444666
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 0033003
# Q $668,222                       T 668222     ☑ G 668222
# Q $72,222                        T 72222      ☑ G 72222
# Q $188,888                       T 188888     ☒ G 118888
# Q $3,371,135                     T 3371135    ☒ G 3331111
# Q $833,999                       T 833999     ☒ G 333999
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 0033003
# Q $4,222,222                     T 4222222    ☑ G 4222222
#
# --------------------------------------------------
# Iteration 117
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 44s 19ms/sample - loss: 0.0151 - acc: 0.9954 - val_loss: 0.1805 - val_acc: 0.9403
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $9,999,999                     T 9999999    ☑ G 9999999
# Q $2,127,111                     T 2127111    ☒ G 2122111
# Q $744,444                       T 744444     ☑ G 744444
# Q $3,371,135                     T 3371135    ☒ G 333111
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 9333333
# Q $733,333                       T 733333     ☑ G 733333
# Q -                              T 1          ☒ G 4
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 9333333
# Q $333,333                       T 333333     ☑ G 333333
#
# --------------------------------------------------
# Iteration 118
# Train on 2300 samples, validate on 62 samples
# 2300/2300 [==============================] - 44s 19ms/sample - loss: 0.0154 - acc: 0.9951 - val_loss: 0.1852 - val_acc: 0.9452
# Q $177,777                       T 177777     ☑ G 177777
# Q $989,999                       T 989999     ☒ G 999999
# Q $421,111                       T 421111     ☑ G 421111
# Q $37,777 - $388,577             T 37777      ☑ G 37777
# Q $445,522                       T 445522     ☑ G 445522
# Q $77,777                        T 77777      ☑ G 77777
# Q $936,666                       T 936666     ☑ G 936666
# Q $1,711,111                     T 1711111    ☒ G 1111111
# Q $3,333,333                     T 3333333    ☑ G 3333333
# Q $8,033,300 - $3,800,000        T 8033300    ☒ G 8033303
#
# --------------------------------------------------
# Iteration 119
# Train on 2300 samples, validate on 62 samples
#  192/2300 [=>............................] - ETA: 30s - loss: 0.0118 - acc: 0.9964
